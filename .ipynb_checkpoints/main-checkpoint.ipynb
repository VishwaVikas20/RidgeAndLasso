# %%
import numpy as np

# %% [markdown]
# ## Ridge Regression:
# ####       it has closed form solution,
# ####       The solution is obtained by minimizing
# ###        RSS(weights,alpha)= MSE+ alpha*(sum of squared weights)

# %%
class Ridge:
    def __init__(self,alpha):
        self.weights=None
        self.alpha=alpha
    def predict(self,X):
        X=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        prediction=X@self.weights
        return prediction
    def fit(self,X,y):
        X=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        a=X.T@X+self.alpha*np.identity(X.shape[1])
        b=X.T@y
        self.weights=np.linalg.inv(a)@b
    def MSE(self,y,y_hat):
        mse=0
        for r,s in zip(y,y_hat):
            mse+=(r-s)**2
        return float(mse)
    def __repr__(self,):
        return f"Ridge Regressor :\n -> Alpha = {self.alpha}\n -> Weights = {self.weights} "

# %%
model=Ridge(3)
X=np.array(
    [[2,4,6],
    [3,6,9],
    [4,8,12]]
)
y=np.array([2,3,4])
model.fit(X,y)

# %%
model.predict(np.array([[5,10,15]]))
# Out:
# array([4.95227273])

# %%
lam=np.arange(0.25,10,0.25)
best_model=None
best_mse=float('inf')
for l in lam:
    model=Ridge(l)
    model.fit(X,y)
    y_hat=model.predict(X)
    mse=model.MSE(y,y_hat)
    print(model)
    if mse<best_mse:
        best_model=model
        best_mse=mse
print("*"*60)
print(f"Best model is \n {best_model}")
print("*"*60)
# Out:
# Ridge Regressor :
#  -> Alpha = 0.25
#  -> Weights = [0.01207648 0.07111707 0.14223415 0.21335122]
# Ridge Regressor :
#  -> Alpha = 0.5
#  -> Weights = [0.01558442 0.07099567 0.14199134 0.21298701]
# Ridge Regressor :
#  -> Alpha = 0.75
#  -> Weights = [0.01724964 0.07091519 0.14183038 0.21274557]
# Ridge Regressor :
#  -> Alpha = 1.0
#  -> Weights = [0.01821862 0.0708502  0.1417004  0.21255061]
# Ridge Regressor :
#  -> Alpha = 1.25
#  -> Weights = [0.01885014 0.07079275 0.14158551 0.21237826]
# Ridge Regressor :
#  -> Alpha = 1.5
#  -> Weights = [0.0192926  0.07073955 0.1414791  0.21221865]
# Ridge Regressor :
#  -> Alpha = 1.75
#  -> Weights = [0.01961853 0.07068898 0.14137797 0.21206695]
# Ridge Regressor :
#  -> Alpha = 2.0
#  -> Weights = [0.01986755 0.07064018 0.14128035 0.21192053]
# Ridge Regressor :
#  -> Alpha = 2.25
#  -> Weights = [0.02006316 0.07059261 0.14118521 0.21177782]
# Ridge Regressor :
#  -> Alpha = 2.5
#  -> Weights = [0.02022018 0.07054594 0.14109189 0.21163783]
# Ridge Regressor :
#  -> Alpha = 2.75
#  -> Weights = [0.02034839 0.07049997 0.14099995 0.21149992]
# Ridge Regressor :
#  -> Alpha = 3.0
#  -> Weights = [0.02045455 0.07045455 0.14090909 0.21136364]
# Ridge Regressor :
#  -> Alpha = 3.25
#  -> Weights = [0.02054344 0.07040955 0.1408191  0.21122866]
# Ridge Regressor :
#  -> Alpha = 3.5
#  -> Weights = [0.02061856 0.07036492 0.14072983 0.21109475]
# Ridge Regressor :
#  -> Alpha = 3.75
#  -> Weights = [0.02068252 0.07032058 0.14064116 0.21096174]
# Ridge Regressor :
#  -> Alpha = 4.0
#  -> Weights = [0.02073733 0.0702765  0.140553   0.21082949]
# Ridge Regressor :
#  -> Alpha = 4.25
#  -> Weights = [0.02078451 0.07023264 0.14046527 0.21069791]
# Ridge Regressor :
#  -> Alpha = 4.5
#  -> Weights = [0.0208253  0.07018897 0.14037794 0.21056691]
# Ridge Regressor :
#  -> Alpha = 4.75
#  -> Weights = [0.02086065 0.07014548 0.14029095 0.21043643]
# Ridge Regressor :
#  -> Alpha = 5.0
#  -> Weights = [0.02089136 0.07010214 0.14020427 0.21030641]
# Ridge Regressor :
#  -> Alpha = 5.25
#  -> Weights = [0.02091807 0.07005894 0.14011787 0.21017681]
# Ridge Regressor :
#  -> Alpha = 5.5
#  -> Weights = [0.0209413  0.07001586 0.14003173 0.21004759]
# Ridge Regressor :
#  -> Alpha = 5.75
#  -> Weights = [0.02096149 0.06997291 0.13994582 0.20991874]
# Ridge Regressor :
#  -> Alpha = 6.0
#  -> Weights = [0.02097902 0.06993007 0.13986014 0.20979021]
# Ridge Regressor :
#  -> Alpha = 6.25
#  -> Weights = [0.02099419 0.06988733 0.13977466 0.20966199]
# Ridge Regressor :
#  -> Alpha = 6.5
#  -> Weights = [0.02100727 0.06984469 0.13968938 0.20953407]
# Ridge Regressor :
#  -> Alpha = 6.75
#  -> Weights = [0.02101849 0.06980214 0.13960428 0.20940642]
# Ridge Regressor :
#  -> Alpha = 7.0
#  -> Weights = [0.02102804 0.06975968 0.13951936 0.20927904]
# Ridge Regressor :
#  -> Alpha = 7.25
#  -> Weights = [0.02103609 0.0697173  0.1394346  0.20915191]
# Ridge Regressor :
#  -> Alpha = 7.5
#  -> Weights = [0.02104279 0.06967501 0.13935001 0.20902502]
# Ridge Regressor :
#  -> Alpha = 7.75
#  -> Weights = [0.02104826 0.06963279 0.13926557 0.20889836]
# Ridge Regressor :
#  -> Alpha = 8.0
#  -> Weights = [0.02105263 0.06959064 0.13918129 0.20877193]
# Ridge Regressor :
#  -> Alpha = 8.25
#  -> Weights = [0.02105599 0.06954857 0.13909714 0.20864572]
# Ridge Regressor :
#  -> Alpha = 8.5
#  -> Weights = [0.02105843 0.06950657 0.13901314 0.20851972]
# Ridge Regressor :
#  -> Alpha = 8.75
#  -> Weights = [0.02106002 0.06946464 0.13892928 0.20839392]
# Ridge Regressor :
#  -> Alpha = 9.0
#  -> Weights = [0.02106084 0.06942278 0.13884555 0.20826833]
# Ridge Regressor :
#  -> Alpha = 9.25
#  -> Weights = [0.02106095 0.06938098 0.13876196 0.20814294]
# Ridge Regressor :
#  -> Alpha = 9.5
#  -> Weights = [0.02106041 0.06933925 0.13867849 0.20801774]
# Ridge Regressor :
#  -> Alpha = 9.75
#  -> Weights = [0.02105926 0.06929757 0.13859515 0.20789272]
# ************************************************************
# Best model is
#  Ridge Regressor :
#  -> Alpha = 0.25
#  -> Weights = [0.01207648 0.07111707 0.14223415 0.21335122]
# ************************************************************

# %% [markdown]
# ## LASSO Regression :
# #### Lasso doesn't have any closed form solutio.
# #### We continously reweight such that it minimizes the loss function.
# #### For lasso the loss function is
# ###   RSS(weights,alpha)=MSE+alpha*(sum of absolute values of weights)
# ###   $$J(w) = \text{MSE} + \alpha \sum_{j=1}^{d} |w_j|$$
# #### Lasso can converge a weight to zero, that means it can also identify the likely unnecessary variables

# %% [markdown]
# ## Approach 1: Subgradient Descent
#
# ### Mathematical Overview
# ### Because $|w|$ has a sharp corner at zero, we use the subgradient of the penalty term, which translates directly to the element-wise sign of the weights:
# ## $$\nabla \Omega(w) = \alpha \cdot \text{sign}(w)$$
#
# ### Implementation

# %%
class LassoSubgradientDescent:
    def __init__(self,alpha):
        self.alpha=alpha
        self.weights=None
    def predict(self,X):
        X=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        prediction=X@self.weights
        return prediction
    def MSE(self,y,y_hat):
        mse=0
        for r,s in zip(y,y_hat):
            mse+=(r-s)**2
        return mse
    def fit(self,X,y,max_iter,learning_rate):
        self.weights=np.random.rand(X.shape[1]+1)
        
        X_expanded=X=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        for _ in range(max_iter):
            cost=self.MSE(y,y_hat)+self.alpha*np.sum(np.abs(self.weights))
            p=X_expanded@self.weights
            w_grad_mse=(-2*X_expanded.T@(y-p))/len(y)
            w_grad_penality=self.alpha*np.sign(self.weights)
            grad=w_grad_mse+w_grad_penality
            self.weights-=learning_rate*grad
            print(f"Iternation {_+1} | Loss = {cost}")
            
    def __repr__(self,):
        return f"Lasso Regressor(SubgradientDescent) :\n -> Alpha = {self.alpha}\n -> Weights = {self.weights} "

# %%
X_test = np.array([
    [1.0, 2.0, 3.0],
    [2.0, 4.0, 5.0],
    [3.0, 5.0, 1.0],
    [4.0, 1.0, 2.0]
])

# True relationship: y = 5 + 2*x1 + 0*x2 - 3*x3
y_test = np.array([0.0, 0.0, 8.0, 7.0]) 
model = LassoSubgradientDescent(alpha=0.1)
model.fit(X_test, y_test, max_iter=30, learning_rate=0.0001)
# Out:
# Iternation 1 | Loss = 29.45430973244344
# Iternation 2 | Loss = 29.453994950033554
# Iternation 3 | Loss = 29.45368179265279
# Iternation 4 | Loss = 29.45337025210457
# Iternation 5 | Loss = 29.453060320233554
# Iternation 6 | Loss = 29.452751988925453
# Iternation 7 | Loss = 29.452445250106802
# Iternation 8 | Loss = 29.45214009574478
# Iternation 9 | Loss = 29.451836517846985
# Iternation 10 | Loss = 29.451534508461233
# Iternation 11 | Loss = 29.451234059675365
# Iternation 12 | Loss = 29.45093516361704
# Iternation 13 | Loss = 29.450637812453532
# Iternation 14 | Loss = 29.45034199839154
# Iternation 15 | Loss = 29.45004771367698
# Iternation 16 | Loss = 29.449754950594784
# Iternation 17 | Loss = 29.449463701468726
# Iternation 18 | Loss = 29.449173958661195
# Iternation 19 | Loss = 29.44888571457303
# Iternation 20 | Loss = 29.44859896164331
# Iternation 21 | Loss = 29.448313692349156
# Iternation 22 | Loss = 29.448029899205565
# Iternation 23 | Loss = 29.44774757476519
# Iternation 24 | Loss = 29.447466711618173
# Iternation 25 | Loss = 29.44718730239194
# Iternation 26 | Loss = 29.44690933975102
# Iternation 27 | Loss = 29.446632816396868
# Iternation 28 | Loss = 29.44635772506766
# Iternation 29 | Loss = 29.44608405853813
# Iternation 30 | Loss = 29.44581180961936

# %%
print(model)
# Out:
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 0.1
#  -> Weights = [0.32468499 0.8707326  0.06298775 0.82744875]

# %%
lam=np.arange(0.25,3,0.25)
best_model=None
best_cost=float('inf')
for l in lam:
    model=LassoSubgradientDescent(l)
    model.fit(X,y,max_iter=30,learning_rate=0.001)
    print(model)
    y_hat=model.predict(X)
    cost=model.MSE(y,y_hat)+model.alpha*np.sum(np.abs(model.weights))
    if cost<best_cost:
        best_model=model
        best_cost=cost
print("*"*60)
print(f"Best model is \n {best_model}")
print(f"Cost value of best_model is {best_cost}")
print("*"*60)
# Out:
# Iternation 1 | Loss = 0.515382980662654
# Iternation 2 | Loss = 0.4422220856228612
# Iternation 3 | Loss = 0.39469501175757815
# Iternation 4 | Loss = 0.38033060982772054
# Iternation 5 | Loss = 0.3698135302841177
# Iternation 6 | Loss = 0.3620952664937896
# Iternation 7 | Loss = 0.3564130609989796
# Iternation 8 | Loss = 0.3522120303862914
# Iternation 9 | Loss = 0.34908851344020475
# Iternation 10 | Loss = 0.3467488586061026
# Iternation 11 | Loss = 0.3449794430927498
# Iternation 12 | Loss = 0.34362486265913583
# Iternation 13 | Loss = 0.34257206533169776
# Iternation 14 | Loss = 0.3417388091544878
# Iternation 15 | Loss = 0.34106526554497735
# Iternation 16 | Loss = 0.3405079109846042
# Iternation 17 | Loss = 0.34003508340493177
# Iternation 18 | Loss = 0.3396237495904592
# Iternation 19 | Loss = 0.33925715356010494
# Iternation 20 | Loss = 0.3389231058345285
# Iternation 21 | Loss = 0.33861273892887894
# Iternation 22 | Loss = 0.33831960201070466
# Iternation 23 | Loss = 0.3380390022904518
# Iternation 24 | Loss = 0.33776752590259873
# Iternation 25 | Loss = 0.3375026893609007
# Iternation 26 | Loss = 0.33724268600242463
# Iternation 27 | Loss = 0.3369862015331095
# Iternation 28 | Loss = 0.3367322798426361
# Iternation 29 | Loss = 0.3364802253887272
# Iternation 30 | Loss = 0.33622953218462254
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 0.25
#  -> Weights = [ 0.63354209  0.11647726 -0.18136846  0.34919832]
# Iternation 1 | Loss = 0.4770057606875504
# Iternation 2 | Loss = 0.48405434180453566
# Iternation 3 | Loss = 0.4890999901819031
# Iternation 4 | Loss = 0.49268857166629365
# Iternation 5 | Loss = 0.4952171874596527
# Iternation 6 | Loss = 0.49697471690002637
# Iternation 7 | Loss = 0.49817131113133883
# Iternation 8 | Loss = 0.4989598488728283
# Iternation 9 | Loss = 0.49945154485453547
# Iternation 10 | Loss = 0.4997273044908851
# Iternation 11 | Loss = 0.49984598406872804
# Iternation 12 | Loss = 0.4998503997889908
# Iternation 13 | Loss = 0.49977169916613584
# Iternation 14 | Loss = 0.4996325410915331
# Iternation 15 | Loss = 0.49944940923518255
# Iternation 16 | Loss = 0.4992342949768087
# Iternation 17 | Loss = 0.49899592168828577
# Iternation 18 | Loss = 0.498740635362767
# Iternation 19 | Loss = 0.49847305252094254
# Iternation 20 | Loss = 0.49819653154361465
# Iternation 21 | Loss = 0.49791351555215646
# Iternation 22 | Loss = 0.49762578184387096
# Iternation 23 | Loss = 0.49733462334880985
# Iternation 24 | Loss = 0.49704098063422575
# Iternation 25 | Loss = 0.49674553793389253
# Iternation 26 | Loss = 0.49644879300658573
# Iternation 27 | Loss = 0.4961511079560543
# Iternation 28 | Loss = 0.49585274620104147
# Iternation 29 | Loss = 0.4955538993698777
# Iternation 30 | Loss = 0.495254706865499
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 0.5
#  -> Weights = [0.10726056 0.51999061 0.1538703  0.0424593 ]
# Iternation 1 | Loss = 0.9005187379798693
# Iternation 2 | Loss = 0.8206294161752851
# Iternation 3 | Loss = 0.7623219168965536
# Iternation 4 | Loss = 0.7197145700696396
# Iternation 5 | Loss = 0.6885286352726542
# Iternation 6 | Loss = 0.6656514558330516
# Iternation 7 | Loss = 0.6488186663982844
# Iternation 8 | Loss = 0.6363830083750668
# Iternation 9 | Loss = 0.6271461500226551
# Iternation 10 | Loss = 0.6202363405620422
# Iternation 11 | Loss = 0.615019407171443
# Iternation 12 | Loss = 0.611034007941987
# Iternation 13 | Loss = 0.6079445303245822
# Iternation 14 | Loss = 0.6055068261479141
# Iternation 15 | Loss = 0.6035432848609726
# Iternation 16 | Loss = 0.6019247000567818
# Iternation 17 | Loss = 0.6005570779065863
# Iternation 18 | Loss = 0.5993720406872294
# Iternation 19 | Loss = 0.5983198456321291
# Iternation 20 | Loss = 0.5973643063525548
# Iternation 21 | Loss = 0.596479098322328
# Iternation 22 | Loss = 0.5956450712275935
# Iternation 23 | Loss = 0.5948482937810399
# Iternation 24 | Loss = 0.5940786313822747
# Iternation 25 | Loss = 0.5933287114079591
# Iternation 26 | Loss = 0.5925931704910892
# Iternation 27 | Loss = 0.591868106939014
# Iternation 28 | Loss = 0.5911506823837939
# Iternation 29 | Loss = 0.5904388319946586
# Iternation 30 | Loss = 0.5897310536661727
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 0.75
#  -> Weights = [0.4039781  0.00652925 0.24871418 0.11776727]
# Iternation 1 | Loss = 1.603546427314664
# Iternation 2 | Loss = 1.4982331031147096
# Iternation 3 | Loss = 1.4880476282175576
# Iternation 4 | Loss = 1.479542092246268
# Iternation 5 | Loss = 1.4722587001114522
# Iternation 6 | Loss = 1.4658644194670405
# Iternation 7 | Loss = 1.4601169791599564
# Iternation 8 | Loss = 1.4548401341113655
# Iternation 9 | Loss = 1.4499056712518905
# Iternation 10 | Loss = 1.4452203193735138
# Iternation 11 | Loss = 1.4407162264353366
# Iternation 12 | Loss = 1.436344032086134
# Iternation 13 | Loss = 1.432067828130116
# Iternation 14 | Loss = 1.4278614924153297
# Iternation 15 | Loss = 1.4237060218462798
# Iternation 16 | Loss = 1.4195875922297627
# Iternation 17 | Loss = 1.415496146870289
# Iternation 18 | Loss = 1.4114243698151434
# Iternation 19 | Loss = 1.4073669389206398
# Iternation 20 | Loss = 1.4033199824799867
# Iternation 21 | Loss = 1.3992806839361867
# Iternation 22 | Loss = 1.3952469943224057
# Iternation 23 | Loss = 1.3912174230708707
# Iternation 24 | Loss = 1.3871908858325546
# Iternation 25 | Loss = 1.3831665937705133
# Iternation 26 | Loss = 1.3791439730240729
# Iternation 27 | Loss = 1.3751226061214163
# Iternation 28 | Loss = 1.3711021893589797
# Iternation 29 | Loss = 1.3670825017962274
# Iternation 30 | Loss = 1.3630633827002714
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 1.0
#  -> Weights = [ 0.17907669  0.21446812  0.69957012 -0.2234168 ]
# Iternation 1 | Loss = 3.5818725103313986
# Iternation 2 | Loss = 3.0427737419221192
# Iternation 3 | Loss = 2.6500659014001537
# Iternation 4 | Loss = 2.363853163782246
# Iternation 5 | Loss = 2.155112500435939
# Iternation 6 | Loss = 2.002730519385378
# Iternation 7 | Loss = 1.8913478545760223
# Iternation 8 | Loss = 1.8097910230400625
# Iternation 9 | Loss = 1.7757451681457008
# Iternation 10 | Loss = 1.7675167774187257
# Iternation 11 | Loss = 1.7597973220210381
# Iternation 12 | Loss = 1.7524481644461063
# Iternation 13 | Loss = 1.7453684500139277
# Iternation 14 | Loss = 1.7384848099294603
# Iternation 15 | Loss = 1.7317438705632338
# Iternation 16 | Loss = 1.7251068041753046
# Iternation 17 | Loss = 1.7185453647286597
# Iternation 18 | Loss = 1.712039004061121
# Iternation 19 | Loss = 1.7055727739859914
# Iternation 20 | Loss = 1.6991358001325387
# Iternation 21 | Loss = 1.6927201717102425
# Iternation 22 | Loss = 1.6863201338452307
# Iternation 23 | Loss = 1.6799315000290118
# Iternation 24 | Loss = 1.6735512246923616
# Iternation 25 | Loss = 1.667177092265514
# Iternation 26 | Loss = 1.660807490978675
# Iternation 27 | Loss = 1.6544412483086128
# Iternation 28 | Loss = 1.6480775112709345
# Iternation 29 | Loss = 1.6417156593362698
# Iternation 30 | Loss = 1.63535524107938
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 1.25
#  -> Weights = [ 0.68576223  0.2695305   0.30881017 -0.03375957]
# Iternation 1 | Loss = 2.6448803633332574
# Iternation 2 | Loss = 2.281767338285306
# Iternation 3 | Loss = 2.0168924937581845
# Iternation 4 | Loss = 1.8360822647327835
# Iternation 5 | Loss = 1.7785972051031556
# Iternation 6 | Loss = 1.73455777802754
# Iternation 7 | Loss = 1.7002997258051025
# Iternation 8 | Loss = 1.6731574096978203
# Iternation 9 | Loss = 1.6511916566255775
# Iternation 10 | Loss = 1.6329917757139547
# Iternation 11 | Loss = 1.617531531208604
# Iternation 12 | Loss = 1.608058772302659
# Iternation 13 | Loss = 1.5968517001435396
# Iternation 14 | Loss = 1.590021900326865
# Iternation 15 | Loss = 1.5809173997979067
# Iternation 16 | Loss = 1.574502092614528
# Iternation 17 | Loss = 1.5666370223858992
# Iternation 18 | Loss = 1.5606276058046649
# Iternation 19 | Loss = 1.5532319492914284
# Iternation 20 | Loss = 1.5476238199021843
# Iternation 21 | Loss = 1.5402901253600771
# Iternation 22 | Loss = 1.5350807958891577
# Iternation 23 | Loss = 1.5275934856118245
# Iternation 24 | Loss = 1.5227815886866463
# Iternation 25 | Loss = 1.5150266272021287
# Iternation 26 | Loss = 1.5106113881303862
# Iternation 27 | Loss = 1.5025284774301966
# Iternation 28 | Loss = 1.498509435187724
# Iternation 29 | Loss = 1.4902050950813142
# Iternation 30 | Loss = 1.4861068149549352
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 1.5
#  -> Weights = [ 1.81348170e-04  7.46187793e-01 -5.59517253e-02  1.18256921e-01]
# Iternation 1 | Loss = 4.561860306763503
# Iternation 2 | Loss = 3.918244388198061
# Iternation 3 | Loss = 3.4490201066590895
# Iternation 4 | Loss = 3.1066606551116633
# Iternation 5 | Loss = 2.8565916919512655
# Iternation 6 | Loss = 2.6736614097638913
# Iternation 7 | Loss = 2.6439645250049506
# Iternation 8 | Loss = 2.627338500560107
# Iternation 9 | Loss = 2.611874400434407
# Iternation 10 | Loss = 2.597255684301746
# Iternation 11 | Loss = 2.583252078453092
# Iternation 12 | Loss = 2.5696960655830736
# Iternation 13 | Loss = 2.5564657818074705
# Iternation 14 | Loss = 2.543472574751017
# Iternation 15 | Loss = 2.5306519524255533
# Iternation 16 | Loss = 2.5179569988074935
# Iternation 17 | Loss = 2.5053535838658516
# Iternation 18 | Loss = 2.492816878999793
# Iternation 19 | Loss = 2.4803288221228668
# Iternation 20 | Loss = 2.467876273587017
# Iternation 21 | Loss = 2.455449674672034
# Iternation 22 | Loss = 2.443042071676441
# Iternation 23 | Loss = 2.4306484059725757
# Iternation 24 | Loss = 2.4182649975427393
# Iternation 25 | Loss = 2.405889169267067
# Iternation 26 | Loss = 2.3935189736041043
# Iternation 27 | Loss = 2.3811529937590405
# Iternation 28 | Loss = 2.368790199039501
# Iternation 29 | Loss = 2.356429839631173
# Iternation 30 | Loss = 2.344071370050203
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 1.75
#  -> Weights = [ 0.51996951  0.42805076  0.31119385 -0.07122936]
# Iternation 1 | Loss = 2.9297971365654636
# Iternation 2 | Loss = 2.6551816263762964
# Iternation 3 | Loss = 2.4540970892712757
# Iternation 4 | Loss = 2.306504268235171
# Iternation 5 | Loss = 2.197825198509243
# Iternation 6 | Loss = 2.117454843368237
# Iternation 7 | Loss = 2.0576783533205996
# Iternation 8 | Loss = 2.0128834043107973
# Iternation 9 | Loss = 1.9789871971381423
# Iternation 10 | Loss = 1.9530196165398026
# Iternation 11 | Loss = 1.9328199917949158
# Iternation 12 | Loss = 1.9168164990637828
# Iternation 13 | Loss = 1.9038656831366438
# Iternation 14 | Loss = 1.8931357142686718
# Iternation 15 | Loss = 1.884021460992195
# Iternation 16 | Loss = 1.8760827081081035
# Iternation 17 | Loss = 1.8689992121081962
# Iternation 18 | Loss = 1.8625380053288263
# Iternation 19 | Loss = 1.8565296106930445
# Iternation 20 | Loss = 1.850850738641419
# Iternation 21 | Loss = 1.8454116996627363
# Iternation 22 | Loss = 1.840147247283664
# Iternation 23 | Loss = 1.8350099166154965
# Iternation 24 | Loss = 1.8299651783446165
# Iternation 25 | Loss = 1.8249879134043745
# Iternation 26 | Loss = 1.8200598484035126
# Iternation 27 | Loss = 1.8151676899764506
# Iternation 28 | Loss = 1.8103017675784925
# Iternation 29 | Loss = 1.8054550461596175
# Iternation 30 | Loss = 1.8006224079139648
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 2.0
#  -> Weights = [0.40042183 0.15717377 0.26458931 0.04769479]
# Iternation 1 | Loss = 4.133661780025512
# Iternation 2 | Loss = 3.46674281045584
# Iternation 3 | Loss = 2.9799571106831677
# Iternation 4 | Loss = 2.624213159784376
# Iternation 5 | Loss = 2.3637983332326464
# Iternation 6 | Loss = 2.1727327565635126
# Iternation 7 | Loss = 2.032116842129178
# Iternation 8 | Loss = 1.928201700808484
# Iternation 9 | Loss = 1.850985423793249
# Iternation 10 | Loss = 1.793191919248128
# Iternation 11 | Loss = 1.7495280462872778
# Iternation 12 | Loss = 1.7271082521579726
# Iternation 13 | Loss = 1.7017562268245938
# Iternation 14 | Loss = 1.689634461869522
# Iternation 15 | Loss = 1.6736127815919823
# Iternation 16 | Loss = 1.668470546780442
# Iternation 17 | Loss = 1.6561972412766783
# Iternation 18 | Loss = 1.6545845172486804
# Iternation 19 | Loss = 1.6464780325080515
# Iternation 20 | Loss = 1.644439621858288
# Iternation 21 | Loss = 1.6398374849160469
# Iternation 22 | Loss = 1.6363145869180058
# Iternation 23 | Loss = 1.634826055509107
# Iternation 24 | Loss = 1.6292586839508576
# Iternation 25 | Loss = 1.6306766272335391
# Iternation 26 | Loss = 1.6236156891710591
# Iternation 27 | Loss = 1.6248092932919072
# Iternation 28 | Loss = 1.620446688551973
# Iternation 29 | Loss = 1.6189610195893627
# Iternation 30 | Loss = 1.6172724859827163
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 2.25
#  -> Weights = [-0.00057768  0.46321237  0.1453205   0.06546041]
# Iternation 1 | Loss = 6.295274418853987
# Iternation 2 | Loss = 5.539929074301002
# Iternation 3 | Loss = 4.988392022552977
# Iternation 4 | Loss = 4.677904789218795
# Iternation 5 | Loss = 4.639419137337812
# Iternation 6 | Loss = 4.604569954528012
# Iternation 7 | Loss = 4.572366433686989
# Iternation 8 | Loss = 4.542087792020748
# Iternation 9 | Loss = 4.513209681405743
# Iternation 10 | Loss = 4.4853506541112935
# Iternation 11 | Loss = 4.458233218201457
# Iternation 12 | Loss = 4.431655506495713
# Iternation 13 | Loss = 4.405470666578689
# Iternation 14 | Loss = 4.379571867643897
# Iternation 15 | Loss = 4.353881393417537
# Iternation 16 | Loss = 4.328342707584271
# Iternation 17 | Loss = 4.302914681619955
# Iternation 18 | Loss = 4.277567395711257
# Iternation 19 | Loss = 4.2522790840493165
# Iternation 20 | Loss = 4.227033912621523
# Iternation 21 | Loss = 4.201820362621003
# Iternation 22 | Loss = 4.176630054424985
# Iternation 23 | Loss = 4.151456892073976
# Iternation 24 | Loss = 4.126296440905743
# Iternation 25 | Loss = 4.101145474802508
# Iternation 26 | Loss = 4.076001646826728
# Iternation 27 | Loss = 4.050863249618383
# Iternation 28 | Loss = 4.025729041091131
# Iternation 29 | Loss = 4.000598117631422
# Iternation 30 | Loss = 3.975469821854625
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 2.5
#  -> Weights = [ 0.48060422  0.61505812  0.31992957 -0.13560967]
# Iternation 1 | Loss = 3.86398016271162
# Iternation 2 | Loss = 3.4082503219465097
# Iternation 3 | Loss = 3.0911985250426848
# Iternation 4 | Loss = 2.8570400083858365
# Iternation 5 | Loss = 2.683184253162373
# Iternation 6 | Loss = 2.5531973273394133
# Iternation 7 | Loss = 2.455124033048616
# Iternation 8 | Loss = 2.380267318604108
# Iternation 9 | Loss = 2.340626101087698
# Iternation 10 | Loss = 2.3100009294534343
# Iternation 11 | Loss = 2.2877528786233827
# Iternation 12 | Loss = 2.264148142854595
# Iternation 13 | Loss = 2.255241266304083
# Iternation 14 | Loss = 2.235137055611843
# Iternation 15 | Loss = 2.2272080809024524
# Iternation 16 | Loss = 2.218293393664997
# Iternation 17 | Loss = 2.2064768305337097
# Iternation 18 | Loss = 2.195523285947371
# Iternation 19 | Loss = 2.1992256267542367
# Iternation 20 | Loss = 2.1884512604806883
# Iternation 21 | Loss = 2.1775184390243627
# Iternation 22 | Loss = 2.173243438737498
# Iternation 23 | Loss = 2.16374467287182
# Iternation 24 | Loss = 2.1780835304335735
# Iternation 25 | Loss = 2.162593340373621
# Iternation 26 | Loss = 2.161142628379576
# Iternation 27 | Loss = 2.151648465775986
# Iternation 28 | Loss = 2.1483323767278533
# Iternation 29 | Loss = 2.1436199205706545
# Iternation 30 | Loss = 2.137435823072935
# Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 2.75
#  -> Weights = [ 2.20797374e-03  6.65928958e-01 -2.85889849e-04  9.18306872e-02]
# ************************************************************
# Best model is
#  Lasso Regressor(SubgradientDescent) :
#  -> Alpha = 0.25
#  -> Weights = [ 0.63354209  0.11647726 -0.18136846  0.34919832]
# Cost value of best_model is 0.4033114152992502
# ************************************************************

# %% [markdown]
# ## Approach 2: Coordinate Descent (Analytical Selection)
#
# ### Mathematical Overview
# #### Instead of updating all weights simultaneously, Coordinate Descent optimizes **one weight at a time** while holding all others constant. It calculates the partial residual $\rho_j$ (the error left over excluding feature $j$) and applies the **Soft-Thresholding Operator**:
#
# ## $$S(\rho_j, \alpha) = \text{sign}(\rho_j) \max(|\rho_j| - \alpha, 0)$$
#
# #### This forces uninformative feature weights to snap cleanly to exactly `0.0`.
#
# ### Update rule:
# $$
# \beta_k =
# \begin{cases}
# \frac{\sum_{i=1}^n r_i^{(k)} x_{ik} - \lambda}{\sum_{i=1}^n x_{ik}^2} & \text{if } \sum_{i=1}^n r_i^{(k)} x_{ik} > \lambda \\
# \frac{\sum_{i=1}^n r_i^{(k)} x_{ik} + \lambda}{\sum_{i=1}^n x_{ik}^2} & \text{if } \sum_{i=1}^n r_i^{(k)} x_{ik} < -\lambda \\
# 0 & \text{if } -\lambda \le \sum_{i=1}^n r_i^{(k)} x_{ik} \le \lambda
# \end{cases}
# $$
#
# #### where $$ r_i^{(k)} = y_i - \sum_{j \neq k} x_{ij}\beta_j $$
# $$r_i^{(k)} = (y_i - \hat{y}_i) + x_{ik}\beta_k$$
#
# ### Implementation

# %%
class LassoCoordinateDescent:
    def __init__(self,alpha):
        self.alpha=alpha
        self.weights=None
    def predict(self,X):
        X=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        prediction=X@self.weights
        return prediction
    def MSE(self,y,y_hat):
        mse=0
        for r,s in zip(y,y_hat):
            mse+=(r-s)**2
        return mse
    def r(self, X_expanded, y, y_hat, k):
        return (y - y_hat) + X_expanded[:, k] * self.weights[k]
    def update_rule(self,X,y,k):
        rtimesx=0
        x_expanded=np.concatenate((np.ones((X.shape[0],1)),X),axis=1)
        y_hat=x_expanded@self.weights
        for r,s in zip(self.r(x_expanded,y,y_hat,k+1),x_expanded[:,k+1]):
            rtimesx+=r*s
        if rtimesx>self.alpha:
            update_value=(rtimesx-self.alpha)/np.sum(x_expanded[:,k+1]**2)
        elif rtimesx<-self.alpha:
            update_value=(rtimesx+self.alpha)/np.sum(x_expanded[:,k+1]**2)
        else:
            update_value=0
        return update_value
            
    def fit(self,X,y,max_iter):
        samples,features=X.shape
        self.weights=np.random.rand(features+1)
        for _ in range(max_iter):
            y_hat_features = X @ self.weights[1:]
            self.weights[0] = np.mean(y - y_hat_features)
            for k in range(features):
                update_value=self.update_rule(X,y,k)
                self.weights[k+1]=update_value
            y_pred=self.predict(X)
            print(f"Iteration : {_+1} | Loss : {self.MSE(y,y_pred)}")
    def __repr__(self,):
        return f"Lasso Regressor(Coordinate Descent) :\n -> Alpha = {self.alpha}\n -> Weights = {self.weights} "

# %%
X_test = np.array([
    [1.0, 2.0, 3.0],
    [2.0, 4.0, 5.0],
    [3.0, 5.0, 1.0],
    [4.0, 1.0, 2.0]
])

# True relationship: y = 5 + 2*x1 + 0*x2 - 3*x3
y_test = np.array([0.0, 0.0, 8.0, 7.0]) 
model = LassoCoordinateDescent(alpha=0.1)
model.fit(X_test, y_test, max_iter=30)
# Out:
# Iteration : 1 | Loss : 40.661035048024466
# Iteration : 2 | Loss : 20.088168939120507
# Iteration : 3 | Loss : 9.835848305642088
# Iteration : 4 | Loss : 4.864347233010137
# Iteration : 5 | Loss : 2.511702309204231
# Iteration : 6 | Loss : 1.4152279307322124
# Iteration : 7 | Loss : 0.9010199409133517
# Iteration : 8 | Loss : 0.6481508455597456
# Iteration : 9 | Loss : 0.5099588915618942
# Iteration : 10 | Loss : 0.4223378193204101
# Iteration : 11 | Loss : 0.3585103329405767
# Iteration : 12 | Loss : 0.3076908155481984
# Iteration : 13 | Loss : 0.26551835145098907
# Iteration : 14 | Loss : 0.2300233476879857
# Iteration : 15 | Loss : 0.20005774872354992
# Iteration : 16 | Loss : 0.17475029462725356
# Iteration : 17 | Loss : 0.15335041649361664
# Iteration : 18 | Loss : 0.13519894655341222
# Iteration : 19 | Loss : 0.11972852051025414
# Iteration : 20 | Loss : 0.10646361549664815
# Iteration : 21 | Loss : 0.0950145799081164
# Iteration : 22 | Loss : 0.08506723157963056
# Iteration : 23 | Loss : 0.07637067098750225
# Iteration : 24 | Loss : 0.06872527905272786
# Iteration : 25 | Loss : 0.06197199168542244
# Iteration : 26 | Loss : 0.05598328818927982
# Iteration : 27 | Loss : 0.05065593367254981
# Iteration : 28 | Loss : 0.045905311024227416
# Iteration : 29 | Loss : 0.04166109483903899
# Iteration : 30 | Loss : 0.037864005390827994

# %%
y_pred=model.predict(X_test)
print(model.MSE(y_test,y_pred))
print(model)
# Out:
# 0.037864005390827994
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 0.1
#  -> Weights = [ 1.887058    1.91409639  0.36466275 -1.45204672]

# %%
lam=np.arange(0.25,3,0.25)
best_model=None
best_cost=float('inf')
for l in lam:
    model=LassoCoordinateDescent(l)
    model.fit(X,y,max_iter=25)
    print(model)
    y_hat=model.predict(X)
    cost=model.MSE(y,y_hat)+model.alpha*np.sum(np.abs(model.weights))
    if cost<best_cost:
        best_model=model
        best_cost=cost
print("*"*60)
print(f"Best model is \n {best_model}")
print(f"Cost value of best_model is {best_cost}")
print("*"*60)
# Out:
# Iteration : 1 | Loss : 1.8970166633682481
# Iteration : 2 | Loss : 1.634373192909675
# Iteration : 3 | Loss : 1.4074293556687025
# Iteration : 4 | Loss : 1.2113810574069424
# Iteration : 5 | Loss : 1.0420674228271067
# Iteration : 6 | Loss : 0.8958848981491617
# Iteration : 7 | Loss : 0.7697128093942471
# Iteration : 8 | Loss : 0.6608488496382289
# Iteration : 9 | Loss : 0.5669531718974897
# Iteration : 10 | Loss : 0.4859999406170664
# Iteration : 11 | Loss : 0.4162353475540873
# Iteration : 12 | Loss : 0.35614123031545664
# Iteration : 13 | Loss : 0.3044035466293346
# Iteration : 14 | Loss : 0.2598850569552538
# Iteration : 15 | Loss : 0.2216016543050786
# Iteration : 16 | Loss : 0.1887018549221614
# Iteration : 17 | Loss : 0.16044902827987476
# Iteration : 18 | Loss : 0.1362060010398461
# Iteration : 19 | Loss : 0.115421718304981
# Iteration : 20 | Loss : 0.097619687709512
# Iteration : 21 | Loss : 0.08238796847216048
# Iteration : 22 | Loss : 0.06937049924797044
# Iteration : 23 | Loss : 0.05825958609886616
# Iteration : 24 | Loss : 0.048789395725247396
# Iteration : 25 | Loss : 0.0407303197488394
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 0.25
#  -> Weights = [-0.44238649 -0.05545608  0.26396005  0.22065159]
# Iteration : 1 | Loss : 15.672804221658538
# Iteration : 2 | Loss : 13.527960645186196
# Iteration : 3 | Loss : 11.672857599177105
# Iteration : 4 | Loss : 10.068626091296444
# Iteration : 5 | Loss : 8.681593006587995
# Iteration : 6 | Loss : 7.482587802246654
# Iteration : 7 | Loss : 6.4463416259523045
# Iteration : 8 | Loss : 5.550966542877813
# Iteration : 9 | Loss : 4.7775041969575724
# Iteration : 10 | Loss : 4.109534653976906
# Iteration : 11 | Loss : 3.5328374066166974
# Iteration : 12 | Loss : 3.0350975899878065
# Iteration : 13 | Loss : 2.605651382281355
# Iteration : 14 | Loss : 2.235265367897576
# Iteration : 15 | Loss : 1.9159453362269918
# Iteration : 16 | Loss : 1.6407705923844471
# Iteration : 17 | Loss : 1.403750378983494
# Iteration : 18 | Loss : 1.1996994611864495
# Iteration : 19 | Loss : 1.0241303200493015
# Iteration : 20 | Loss : 0.8731597396408209
# Iteration : 21 | Loss : 0.7434278685207033
# Iteration : 22 | Loss : 0.632028091953612
# Iteration : 23 | Loss : 0.5364462729509234
# Iteration : 24 | Loss : 0.4545081124088839
# Iteration : 25 | Loss : 0.38433354518524
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 0.5
#  -> Weights = [-1.361243   -1.5187621   0.68058682  0.52476535]
# Iteration : 1 | Loss : 18.16608309605246
# Iteration : 2 | Loss : 15.653888521258317
# Iteration : 3 | Loss : 13.482950932819469
# Iteration : 4 | Loss : 11.607361709719159
# Iteration : 5 | Loss : 9.987357949775724
# Iteration : 6 | Loss : 8.588501818416656
# Iteration : 7 | Loss : 7.3809693389847
# Iteration : 8 | Loss : 6.338934039276156
# Iteration : 9 | Loss : 5.440032812126163
# Iteration : 10 | Loss : 4.664903032147091
# Iteration : 11 | Loss : 3.9967814306657274
# Iteration : 12 | Loss : 3.4211564963745795
# Iteration : 13 | Loss : 2.9254672661133734
# Iteration : 14 | Loss : 2.4988423209807027
# Iteration : 15 | Loss : 2.1318736271045275
# Iteration : 16 | Loss : 1.816420574743375
# Iteration : 17 | Loss : 1.5454401885706248
# Iteration : 18 | Loss : 1.3128400186875644
# Iteration : 19 | Loss : 1.1133506871038867
# Iteration : 20 | Loss : 0.9424154676413088
# Iteration : 21 | Loss : 0.7960946267116458
# Iteration : 22 | Loss : 0.6709825553515258
# Iteration : 23 | Loss : 0.5641359854642822
# Iteration : 24 | Loss : 0.473011810802155
# Iteration : 25 | Loss : 0.3954132304792907
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 0.75
#  -> Weights = [-1.37867592 -1.68601369  0.47029598  0.72155533]
# Iteration : 1 | Loss : 34.933693977804914
# Iteration : 2 | Loss : 30.109550079373157
# Iteration : 3 | Loss : 25.94022295951715
# Iteration : 4 | Loss : 22.337654949405515
# Iteration : 5 | Loss : 19.225574240592145
# Iteration : 6 | Loss : 16.53792125043173
# Iteration : 7 | Loss : 14.21748483561441
# Iteration : 8 | Loss : 12.214720388052706
# Iteration : 9 | Loss : 10.486725573019845
# Iteration : 10 | Loss : 8.996352698846907
# Iteration : 11 | Loss : 7.711439506733934
# Iteration : 12 | Loss : 6.604142595609102
# Iteration : 13 | Loss : 5.650359800142208
# Iteration : 14 | Loss : 4.829229663032767
# Iteration : 15 | Loss : 4.122697722863015
# Iteration : 16 | Loss : 3.5151407084779205
# Iteration : 17 | Loss : 2.9930409180643514
# Iteration : 18 | Loss : 2.5447040901537292
# Iteration : 19 | Loss : 2.1600149657322776
# Iteration : 20 | Loss : 1.8302255137716816
# Iteration : 21 | Loss : 1.5477714626182562
# Iteration : 22 | Loss : 1.3061133605216193
# Iteration : 23 | Loss : 1.0995988920366258
# Iteration : 24 | Loss : 0.9233436134043762
# Iteration : 25 | Loss : 0.7731276482448093
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 1.0
#  -> Weights = [-1.92828035 -2.1346339   0.35686259  1.00261543]
# Iteration : 1 | Loss : 12.115167519259153
# Iteration : 2 | Loss : 10.375873882405564
# Iteration : 3 | Loss : 8.877687488563922
# Iteration : 4 | Loss : 7.587845332551838
# Iteration : 5 | Loss : 6.477992691326981
# Iteration : 6 | Loss : 5.523592943258516
# Iteration : 7 | Loss : 4.7034161989854
# Iteration : 8 | Loss : 3.999096233359259
# Iteration : 9 | Loss : 3.3947466087232603
# Iteration : 10 | Loss : 2.876628093916588
# Iteration : 11 | Loss : 2.4328605357742816
# Iteration : 12 | Loss : 2.053173252060973
# Iteration : 13 | Loss : 1.7286888054109955
# Iteration : 14 | Loss : 1.4517357031362312
# Iteration : 15 | Loss : 1.2156861617392016
# Iteration : 16 | Loss : 1.0148155897968143
# Iteration : 17 | Loss : 0.844180889103384
# Iteration : 18 | Loss : 0.6995150607191345
# Iteration : 19 | Loss : 0.5771359377848674
# Iteration : 20 | Loss : 0.47386715750135516
# Iteration : 21 | Loss : 0.3869697364854793
# Iteration : 22 | Loss : 0.31408283196361186
# Iteration : 23 | Loss : 0.25317246041827185
# Iteration : 24 | Loss : 0.20248710924289878
# Iteration : 25 | Loss : 0.16051931904195507
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 1.25
#  -> Weights = [-0.8642385  -0.56828157 -0.17203739  0.72206683]
# Iteration : 1 | Loss : 11.818158949868387
# Iteration : 2 | Loss : 10.09542921031848
# Iteration : 3 | Loss : 8.61353714394954
# Iteration : 4 | Loss : 7.3396221059166376
# Iteration : 5 | Loss : 6.245253946282083
# Iteration : 6 | Loss : 5.305839235959643
# Iteration : 7 | Loss : 4.500106826589373
# Iteration : 8 | Loss : 3.8096621612570067
# Iteration : 9 | Loss : 3.2186011635999257
# Iteration : 10 | Loss : 2.713175755525355
# Iteration : 11 | Loss : 2.2815041135404646
# Iteration : 12 | Loss : 1.9133196922594928
# Iteration : 13 | Loss : 1.599753839820298
# Iteration : 14 | Loss : 1.3331475200170908
# Iteration : 15 | Loss : 1.1068882540705443
# Iteration : 16 | Loss : 0.9152689133621227
# Iteration : 17 | Loss : 0.7533654437751378
# Iteration : 18 | Loss : 0.6169309917153477
# Iteration : 19 | Loss : 0.5023042394074579
# Iteration : 20 | Loss : 0.4063300495963357
# Iteration : 21 | Loss : 0.3262907733176083
# Iteration : 22 | Loss : 0.2598467941377586
# Iteration : 23 | Loss : 0.2049850727025283
# Iteration : 24 | Loss : 0.15997462047836938
# Iteration : 25 | Loss : 0.12332797460870443
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 1.5
#  -> Weights = [-0.74459287 -0.5019049  -0.20689655  0.70984572]
# Iteration : 1 | Loss : 6.22256802788263
# Iteration : 2 | Loss : 5.268818931707209
# Iteration : 3 | Loss : 4.452272628471645
# Iteration : 4 | Loss : 3.753954581636921
# Iteration : 5 | Loss : 3.157465638628868
# Iteration : 6 | Loss : 2.648635712958715
# Iteration : 7 | Loss : 2.2152238176142083
# Iteration : 8 | Loss : 1.846658261006703
# Iteration : 9 | Loss : 1.5338116420366796
# Iteration : 10 | Loss : 1.268805996135162
# Iteration : 11 | Loss : 1.044844064104218
# Iteration : 12 | Loss : 0.8560631929158428
# Iteration : 13 | Loss : 0.6974088433441967
# Iteration : 14 | Loss : 0.5645250829433315
# Iteration : 15 | Loss : 0.45365979271255563
# Iteration : 16 | Loss : 0.3615826189838712
# Iteration : 17 | Loss : 0.2855139648347479
# Iteration : 18 | Loss : 0.22306354306144657
# Iteration : 19 | Loss : 0.17217721011222564
# Iteration : 20 | Loss : 0.13109097142291679
# Iteration : 21 | Loss : 0.09829119682743173
# Iteration : 22 | Loss : 0.07248021317327734
# Iteration : 23 | Loss : 0.05254655259250692
# Iteration : 24 | Loss : 0.037539231346005335
# Iteration : 25 | Loss : 0.026645517753595686
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 1.75
#  -> Weights = [-0.26846547  0.         -0.03480126  0.37760148]
# Iteration : 1 | Loss : 3.2879719098525224
# Iteration : 2 | Loss : 2.7474514404661914
# Iteration : 3 | Loss : 2.2880346647140963
# Iteration : 4 | Loss : 1.8982916500662375
# Iteration : 5 | Loss : 1.5683580197759062
# Iteration : 6 | Loss : 1.2897234688038859
# Iteration : 7 | Loss : 1.0550486504014682
# Iteration : 8 | Loss : 0.8580066408673777
# Iteration : 9 | Loss : 0.6931456960383144
# Iteration : 10 | Loss : 0.5557704516574358
# Iteration : 11 | Loss : 0.4418390998782594
# Iteration : 12 | Loss : 0.34787440359450583
# Iteration : 13 | Loss : 0.27088669579260627
# Iteration : 14 | Loss : 0.20830725855678067
# Iteration : 15 | Loss : 0.15793069079050512
# Iteration : 16 | Loss : 0.11786505955089305
# Iteration : 17 | Loss : 0.08648879093590635
# Iteration : 18 | Loss : 0.06241339602259944
# Iteration : 19 | Loss : 0.04445124829165885
# Iteration : 20 | Loss : 0.031587733771684626
# Iteration : 21 | Loss : 0.02295718594751244
# Iteration : 22 | Loss : 0.017822096165330023
# Iteration : 23 | Loss : 0.015555158449722545
# Iteration : 24 | Loss : 0.015623766725122836
# Iteration : 25 | Loss : 0.017576633620692582
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 2.0
#  -> Weights = [0.10430559 0.         0.24734494 0.14998364]
# Iteration : 1 | Loss : 3.064148334973363
# Iteration : 2 | Loss : 2.545244065620846
# Iteration : 3 | Loss : 2.1056718238575662
# Iteration : 4 | Loss : 1.734161268969268
# Iteration : 5 | Loss : 1.4209916278968386
# Iteration : 6 | Loss : 1.1577819772396767
# Iteration : 7 | Loss : 0.9373096857645602
# Iteration : 8 | Loss : 0.7533532511950412
# Iteration : 9 | Loss : 0.6005562677230045
# Iteration : 10 | Loss : 0.4743096963322124
# Iteration : 11 | Loss : 0.37064998758386614
# Iteration : 12 | Loss : 0.2861709337271084
# Iteration : 13 | Loss : 0.2179474105725115
# Iteration : 14 | Loss : 0.16346941531972817
# Iteration : 15 | Loss : 0.12058501950226218
# Iteration : 16 | Loss : 0.08745104077235624
# Iteration : 17 | Loss : 0.062490397184109196
# Iteration : 18 | Loss : 0.04435524622602558
# Iteration : 19 | Loss : 0.03189513095018038
# Iteration : 20 | Loss : 0.024129459610342442
# Iteration : 21 | Loss : 0.02022373539308321
# Iteration : 22 | Loss : 0.019469030956805494
# Iteration : 23 | Loss : 0.021264270189510114
# Iteration : 24 | Loss : 0.025100938248670806
# Iteration : 25 | Loss : 0.03054989176217087
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 2.25
#  -> Weights = [0.23218056 0.         0.         0.30069397]
# Iteration : 1 | Loss : 24.553897292862228
# Iteration : 2 | Loss : 20.92703518627517
# Iteration : 3 | Loss : 17.810982664732627
# Iteration : 4 | Loss : 15.135795321231686
# Iteration : 5 | Loss : 12.840975818328449
# Iteration : 6 | Loss : 10.874206656773158
# Iteration : 7 | Loss : 9.190252336373284
# Iteration : 8 | Loss : 7.750008306933769
# Iteration : 9 | Loss : 6.519677120151478
# Iteration : 10 | Loss : 5.470054804903944
# Iteration : 11 | Loss : 4.575912751948189
# Iteration : 12 | Loss : 3.8154623559915386
# Iteration : 13 | Loss : 3.1698913635941857
# Iteration : 14 | Loss : 2.622962349242451
# Iteration : 15 | Loss : 2.1606650193831807
# Iteration : 16 | Loss : 1.7709151514023684
# Iteration : 17 | Loss : 1.4432939341485784
# Iteration : 18 | Loss : 1.168822308305868
# Iteration : 19 | Loss : 0.9397656257545225
# Iteration : 20 | Loss : 0.7494645717937447
# Iteration : 21 | Loss : 0.5921888355432223
# Iteration : 22 | Loss : 0.4630104830891268
# Iteration : 23 | Loss : 0.35769439461530034
# Iteration : 24 | Loss : 0.2726034792007123
# Iteration : 25 | Loss : 0.20461668639787128
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 2.5
#  -> Weights = [-0.93447307 -0.18572768 -0.17241379  0.59727617]
# Iteration : 1 | Loss : 0.3137997198291978
# Iteration : 2 | Loss : 0.23486441835624508
# Iteration : 3 | Loss : 0.17286179186508854
# Iteration : 4 | Loss : 0.12509404298271906
# Iteration : 5 | Loss : 0.0892531903127165
# Iteration : 6 | Loss : 0.06336704874797013
# Iteration : 7 | Loss : 0.04575254908716694
# Iteration : 8 | Loss : 0.0349754095280208
# Iteration : 9 | Loss : 0.029815303801429643
# Iteration : 10 | Loss : 0.029235785249750505
# Iteration : 11 | Loss : 0.03235832539335874
# Iteration : 12 | Loss : 0.03843991151290622
# Iteration : 13 | Loss : 0.04685372226870908
# Iteration : 14 | Loss : 0.05707246491618879
# Iteration : 15 | Loss : 0.0686540135856803
# Iteration : 16 | Loss : 0.08122903652756096
# Iteration : 17 | Loss : 0.09449034217740158
# Iteration : 18 | Loss : 0.10818371023550957
# Iteration : 19 | Loss : 0.1221000054303144
# Iteration : 20 | Loss : 0.13606839889515754
# Iteration : 21 | Loss : 0.14995054569605576
# Iteration : 22 | Loss : 0.1636355874918355
# Iteration : 23 | Loss : 0.17703586701044083
# Iteration : 24 | Loss : 0.19008325635258233
# Iteration : 25 | Loss : 0.20272601440373278
# Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 2.75
#  -> Weights = [0.9164039  0.         0.05360775 0.19225803]
# ************************************************************
# Best model is
#  Lasso Regressor(Coordinate Descent) :
#  -> Alpha = 0.25
#  -> Weights = [-0.44238649 -0.05545608  0.26396005  0.22065159]
# Cost value of best_model is 0.28634387127699806
# ************************************************************
